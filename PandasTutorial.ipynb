# %%
#!/usr/bin/env python
import pandas as pd
Gdata = pd.read_csv('Ptimes.csv')
print(Gdata)
# Out:
#             Network    Station    Channel Location                 Distance  \
# 0    GI HUEH HHZ --    2.15059   83.06340        .  2017-09-08T04:49:57.32Z
# 1    GI PETF HHZ --    4.13226   63.07090        .  2017-09-08T04:50:23.36Z
# 2    GI CHIE HHZ --    4.26002   96.24440        .  2017-09-08T04:50:24.76Z
# 3    SV MTO3 HHZ --    4.26511   98.41140        .  2017-09-08T04:50:24.49Z
# 4    SV SNET BHZ --    4.55643  106.97000       Pn  2017-09-08T04:50:28.48Z
# 5    GI IZAB HHZ --    4.99229   81.74540       Pn  2017-09-08T04:50:34.69Z
# 6    CU TGUH BHZ 00    6.31780   98.33120       Pn  2017-09-08T04:50:55.24Z
# 7      G UNM BHZ 00    6.72410  309.84500       Pn  2017-09-08T04:50:57.25Z
# 8    NU CRIN HHZ --    6.88807  109.19000       Pn  2017-09-08T04:51:00.62Z
# 9    NU CNGN HHZ --    7.27838  109.66500       Pn  2017-09-08T04:51:03.99Z
# 10   IU TEIG BHZ 00    7.29305   44.51500       Pn  2017-09-08T04:51:05.17Z
# ...

# %%
df = pd.DataFrame({'int_col' : [1,2,6,8,-1], 
                   'float_col' : [0.1,0.2,0.2,10.1,None], 
                   'str_col' : ['a','b',None,'c','a']})

# %%
import pandas as pd
Somedata = pd.read_csv('somePtimes.csv')

# %%
Gdata.loc[1,'Location']='XX'
Gdata.loc[2,'Location']='XX'
print(Gdata['Location'])
# Out:
# 0           .
# 1          XX
# 2          XX
# 3           .
# 4          Pn
# 5          Pn
# 6          Pn
# 7          Pn
# 8          Pn
# 9          Pn
# 10         Pn
# 11         Pn
# 12         Pn
# 13          P
# 14          P
# 15          P
# 16          P
# 17          P
# 18          P
# 19          P
# 20          P
# 21          P
# 22          P
# 23          P
# 24          P
# 25          P
# 26          P
# 27          P
# 28          P
# 29          P
#         ...
# 110         P
# 111         P
# 112         P
# 113         P
# 114         P
# 115         P
# 116         P
# 117         P
# 118         P
# 119         P
# 120         P
# 121         P
# 122         P
# 123         P
# 124         P
# 125         P
# 126         P
# 127         P
# 128     PKPdf
# 129     PKPdf
# 130     PKPdf
# 131    PKPpre
# 132     PKPdf
# 133     PKPdf
# 134     PKPdf
# 135     PKPdf
# 136     PKPdf
# 137     PKPdf
# 138     PKPdf
# 139     PKPab
# ...

# %%
outfile = 'fixed2.csv'
Gdata.to_csv(outfile)#,index=False)

# %%
Gdata = pd.read_csv('AllPtimes.csv')

# %%
Gsub = Gdata[['Distance','Arrival Time']]

# %%
Gsub
# Out:
#       Distance             Arrival Time
# 0      2.02720   2017-09-08T04:49:53.1Z
# 1      2.15059  2017-09-08T04:49:57.32Z
# 2      4.13226  2017-09-08T04:50:23.36Z
# 3      4.26002  2017-09-08T04:50:24.76Z
# 4      4.26511  2017-09-08T04:50:24.49Z
# 5      4.55643  2017-09-08T04:50:28.48Z
# 6      4.99229  2017-09-08T04:50:34.69Z
# 7      6.31780  2017-09-08T04:50:55.24Z
# 8      6.72410  2017-09-08T04:50:57.25Z
# 9      6.88807  2017-09-08T04:51:00.62Z
# 10     7.27838  2017-09-08T04:51:03.99Z
# 11     7.29305  2017-09-08T04:51:05.17Z
# 12     7.85332  2017-09-08T04:51:12.87Z
# 13     8.24177   2017-09-08T04:51:19.6Z
# 14    17.99690  2017-09-08T04:53:25.77Z
# 15    18.08360  2017-09-08T04:53:25.56Z
# 16    18.12890  2017-09-08T04:53:27.37Z
# 17    18.14880  2017-09-08T04:53:27.72Z
# 18    18.15380  2017-09-08T04:53:26.48Z
# 19    18.16400  2017-09-08T04:53:28.26Z
# 20    18.16410  2017-09-08T04:53:28.79Z
# 21    18.20650  2017-09-08T04:53:27.94Z
# ...

# %%
#calebl = Gsub[Gsub['Distance'] < 98]
Gtmp = Gsub[Gsub['Distance']<98.0]
print(Gsub[Gsub['Distance']<98.0])
# Out:
#      Distance             Arrival Time
# 0     2.02720   2017-09-08T04:49:53.1Z
# 1     2.15059  2017-09-08T04:49:57.32Z
# 2     4.13226  2017-09-08T04:50:23.36Z
# 3     4.26002  2017-09-08T04:50:24.76Z
# 4     4.26511  2017-09-08T04:50:24.49Z
# 5     4.55643  2017-09-08T04:50:28.48Z
# 6     4.99229  2017-09-08T04:50:34.69Z
# 7     6.31780  2017-09-08T04:50:55.24Z
# 8     6.72410  2017-09-08T04:50:57.25Z
# 9     6.88807  2017-09-08T04:51:00.62Z
# 10    7.27838  2017-09-08T04:51:03.99Z
# 11    7.29305  2017-09-08T04:51:05.17Z
# 12    7.85332  2017-09-08T04:51:12.87Z
# 13    8.24177   2017-09-08T04:51:19.6Z
# 14   17.99690  2017-09-08T04:53:25.77Z
# 15   18.08360  2017-09-08T04:53:25.56Z
# 16   18.12890  2017-09-08T04:53:27.37Z
# 17   18.14880  2017-09-08T04:53:27.72Z
# 18   18.15380  2017-09-08T04:53:26.48Z
# 19   18.16400  2017-09-08T04:53:28.26Z
# 20   18.16410  2017-09-08T04:53:28.79Z
# 21   18.20650  2017-09-08T04:53:27.94Z
# 22   18.29120  2017-09-08T04:53:28.59Z
# ...

# %%
print(Gdata[Gdata['Location']=="P"])
# Out:
# Empty DataFrame
# Columns: [Network, Station, Channel, Location, Distance, Azimuth, Phase, Arrival Time, Status, Residual, Weight]
# Index: []

# %%
Gsub = Gdata[((Gdata['Phase']=='P')|(Gdata['Phase']=='Pn'))&((Gdata['Azimuth']>120)&(Gdata['Azimuth']<300))]

# %%
GNNE = Gsub.rename(columns={'Location':'NNE'})
print(GNNE)
Gsub.rename(columns={'Location':'NNE'},inplace=True)
# Out:
#     Network Station Channel NNE  Distance  Azimuth  Phase  \
# 129      IU    CTAO     BHZ  10   122.862  255.811  PKPdf
# 130      AU     TOO     BHZ  --   123.356  234.947  PKPdf
# 137      II    KAPI     BHZ  10   145.616  283.697  PKPdf
# 138      IU    NWAO     BHZ  10   146.774  232.392  PKPdf
# 139      IU    MBWA     BHZ  10   147.682  254.531  PKPdf
#
#                 Arrival Time     Status  Residual  Weight
# 129  2017-09-08T05:08:09.24Z  automatic       1.0    0.97
# 130  2017-09-08T05:08:12.12Z  automatic       2.9    0.96
# 137  2017-09-08T05:08:51.14Z  automatic       1.5    0.84
# 138  2017-09-08T05:08:52.77Z  automatic       1.2    0.83
# 139  2017-09-08T05:08:53.69Z  automatic       0.6    0.83
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
Gsub
# Out:
#     Network Station Channel Location  Distance  Azimuth Phase  \
# 38       IU    OTAV     BHZ       10   21.0878  132.957     P
# 56       II     NNA     BHZ       10   31.6515  147.219     P
# 58       IU    SAML     BHZ       10   38.5386  126.306     P
# 62       CX    PB12     BHZ       --   40.6314  144.665     P
# 65       CX   PATCX     BHZ       --   42.5153  146.381     P
# 67       BR    VILB     HHZ       --   43.3084  128.272     P
# 68       IU     LVC     BHZ       10   44.6383  146.494     P
# 69       C1    VA02     BHZ       --   44.6644  200.098     P
# 71       IU     LCO     BHZ       10   49.1429  153.059     P
# 72       C1    VA04     BHZ       --   50.4760  163.857     P
# 73        G    TAOE     BHZ       00   51.7954  245.717     P
# 74       IU    PTCN     BHZ       10   53.3828  222.113     P
# 76       HV    NPOC     HHZ       --   58.5422  283.758     P
# 77       HV     UWE     HHZ       --   58.7096  283.812     P
# ...

# %%
Gd = Gdata.dropna()

# %%
print(Gd)
# Out:
#     Network Station Channel Location   Distance    Azimuth   Phase  \
# 0        GI    RETA     HHZ       --    2.02720  105.19000      Pn
# 1        GI    HUEH     HHZ       --    2.15059   83.06340      Pn
# 2        GI    PETF     HHZ       --    4.13226   63.07090      Pn
# 3        GI    CHIE     HHZ       --    4.26002   96.24440      Pn
# 4        SV    MTO3     HHZ       --    4.26511   98.41140      Pn
# 5        SV    SNET     BHZ       --    4.55643  106.97000      Pn
# 6        GI    IZAB     HHZ       --    4.99229   81.74540      Pn
# 7        CU    TGUH     BHZ       00    6.31780   98.33120      Pn
# 8         G     UNM     BHZ       00    6.72410  309.84500      Pn
# 9        NU    CRIN     HHZ       --    6.88807  109.19000      Pn
# 10       NU    CNGN     HHZ       --    7.27838  109.66500      Pn
# 11       IU    TEIG     BHZ       00    7.29305   44.51500      Pn
# 12       NU    MATN     HHZ       --    7.85332  104.73200      Pn
# ...

# %%
Gdata.describe()
# Out:
#          Distance     Azimuth    Residual      Weight
# count  141.000000  141.000000  141.000000  141.000000
# mean    52.383243  174.874915    0.108511    0.788227
# std     37.313490  124.916328    1.291593    0.325397
# min      2.027200    1.393950   -2.900000    0.000000
# 25%     20.497200   55.063200   -0.800000    0.660000
# 50%     45.100800  151.527000    0.100000    0.850000
# 75%     73.342100  313.962000    0.900000    1.060000
# max    147.988000  356.582000    3.900000    1.110000

# %%
GSSW = Gdata[((Gdata['Phase']=='P')|(Gdata['Phase']=='Pn'))&((Gdata['Azimuth']>120)&(Gdata['Azimuth']<300))]

# %%
GNNE = Gdata[((Gdata['Phase']=='P')|(Gdata['Phase']=='Pn'))&((Gdata['Azimuth']<120)&(Gdata['Azimuth']>300))]

# %%
GSSW.describe()
# Out:
#         Distance     Azimuth   Residual     Weight
# count  38.000000   38.000000  38.000000  38.000000
# mean   61.804245  207.308342  -0.189474   1.002368
# std    17.827167   60.769217   1.396867   0.112308
# min    21.087800  126.306000  -2.000000   0.660000
# 25%    50.805850  151.910000  -1.150000   0.962500
# 50%    60.601100  183.867000  -0.200000   1.060000
# 75%    73.130600  270.443250   0.375000   1.060000
# max    99.194000  296.142000   3.900000   1.110000

# %%
Gdata.head()
# Out:
#   Network Station Channel Location  Distance   Azimuth Phase  \
# 0      GI    RETA     HHZ       --   2.02720  105.1900    Pn
# 1      GI    HUEH     HHZ       --   2.15059   83.0634    Pn
# 2      GI    PETF     HHZ       --   4.13226   63.0709    Pn
# 3      GI    CHIE     HHZ       --   4.26002   96.2444    Pn
# 4      SV    MTO3     HHZ       --   4.26511   98.4114    Pn
#
#               Arrival Time  Status  Residual  Weight
# 0   2017-09-08T04:49:53.1Z  manual      -0.2     0.0
# 1  2017-09-08T04:49:57.32Z  manual       2.1     0.0
# 2  2017-09-08T04:50:23.36Z  manual       1.4     0.0
# 3  2017-09-08T04:50:24.76Z  manual       1.0     0.0
# 4  2017-09-08T04:50:24.49Z  manual       0.5     0.0

# %%
GNNE = Gdata[((Gdata['Phase']=='P')|(Gdata['Phase']=='Pn'))&((Gdata['Azimuth']<120))]

# %%
GNNE.describe()
# Out:
#         Distance     Azimuth   Residual     Weight
# count  58.000000   58.000000  58.000000  58.000000
# mean   36.503012   49.239221   0.189655   0.653276
# std    28.897982   36.835119   1.222263   0.404979
# min     2.027200    1.393950  -2.800000   0.000000
# 25%    18.135125   16.410475  -0.775000   0.620000
# 50%    23.194950   37.270200   0.200000   0.710000
# 75%    63.241925   81.250775   1.000000   1.005000
# max    98.476500  109.665000   3.400000   1.110000

# %%
Gsub.loc[Gsub['Azimuth'] >= 300,'Azimuth'] -= 360
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
Gsub = Gdata[((Gdata['Phase']=='P')|(Gdata['Phase']=='Pn'))].copy()

# %%
Gsub.loc[(Gsub['Azimuth'] >= 300 ,'Azimuth'),(Gsub['Azimuth']<= 120 ,'Azimuth')] -= 360
#Gsub.loc[Gsub['Azimuth'] <= 120 ,'Azimuth'] -= 360
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-6f5c347aefb4> in <module>()
# ----> 1 Gsub.loc[(Gsub['Azimuth'] >= 300 ,'Azimuth'),(Gsub['Azimuth']<= 120 ,'Azimuth')] -= 360
#       2 #Gsub.loc[Gsub['Azimuth'] <= 120 ,'Azimuth'] -= 360
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
# ...

# %%
from math import cos
from math import radians

# %%
Gsub['Azimuth'].apply(cos)
# Out:
# 0     -0.942422
# 1      0.888630
# 2     -0.048575
# 3      0.990468
# 4     -0.670132
# 5     -0.131410
# 6     -0.221790
# 7     -0.608514
# 8     -0.176233
# 9      0.869102
# 10     0.546672
# 11     0.242616
# 12    -0.697427
# 13     0.311916
# 14    -0.045296
# 15    -0.848692
# 16     0.826794
# 17     0.534612
# 18     0.999955
# 19     0.953566
# 20     0.954763
# 21    -0.669609
# 22     0.643206
# 23     0.555305
# 24     0.441951
# 25     0.246302
# 26     0.961579
# 27     0.058274
# 28     0.636441
# 29    -0.396512
#          ...
# 99     0.894051
# 100    0.242367
# 101   -0.807229
# 102    0.503304
# 103    0.997585
# 104    0.920413
# 105    0.806631
# 106   -0.720181
# 107   -0.831849
# 108    0.673184
# 109   -0.757934
# 110   -0.946587
# 111    0.888229
# 112   -0.576788
# 113   -0.425222
# 114   -0.934952
# 115    0.860550
# 116   -0.990548
# 117    0.356245
# 118    0.750188
# 119    0.744725
# 120   -0.089152
# 121   -0.945033
# 122   -0.633983
# ...

# %%
def CosAzm30(a):
    return cos(radians(a-30))

# %%
Gsub['Azimuth'].apply(CosAzm30)
# Out:
# 0      0.255614
# 1      0.600931
# 2      0.837996
# 3      0.402836
# 4      0.367940
# 5      0.225461
# 6      0.619157
# 7      0.369241
# 8      0.170983
# 9      0.187553
# 10     0.179403
# 11     0.968082
# 12     0.263334
# 13     0.217820
# 14     0.955323
# 15     0.633516
# 16     0.886655
# 17     0.834675
# 18     0.986851
# 19     0.761516
# 20     0.761470
# 21     0.995703
# 22     0.693163
# 23     0.746754
# 24     0.742134
# 25     0.772889
# 26     0.879485
# 27     0.529253
# 28     0.999310
# 29     0.476606
#          ...
# 99     0.877932
# 100    0.969234
# 101    0.645899
# 102    0.997500
# 103    0.821549
# 104   -0.289951
# 105   -0.611693
# 106    0.346133
# 107   -0.843476
# 108   -0.067284
# 109    0.995046
# 110    0.945262
# 111    0.929477
# 112   -0.725218
# 113   -0.738879
# 114    0.999992
# 115   -0.503955
# 116    0.976026
# 117    0.982404
# 118    0.988134
# 119    0.420877
# 120    0.738832
# 121    0.975278
# 122    0.540240
# ...

# %%
Gsub['New'] = Gsub['Azimuth'].apply(CosAzm30)

# %%
Gsub
# Out:
#     Network Station Channel Location  Distance    Azimuth Phase  \
# 0        GI    RETA     HHZ       --   2.02720 -254.81000    Pn
# 1        GI    HUEH     HHZ       --   2.15059 -276.93660    Pn
# 2        GI    PETF     HHZ       --   4.13226 -296.92910    Pn
# 3        GI    CHIE     HHZ       --   4.26002 -263.75560    Pn
# 4        SV    MTO3     HHZ       --   4.26511 -261.58860    Pn
# 5        SV    SNET     BHZ       --   4.55643 -253.03000    Pn
# 6        GI    IZAB     HHZ       --   4.99229 -278.25460    Pn
# 7        CU    TGUH     BHZ       00   6.31780 -261.66880    Pn
# 8         G     UNM     BHZ       00   6.72410 -410.15500    Pn
# 9        NU    CRIN     HHZ       --   6.88807 -250.81000    Pn
# 10       NU    CNGN     HHZ       --   7.27838 -250.33500    Pn
# 11       IU    TEIG     BHZ       00   7.29305 -315.48500    Pn
# 12       NU    MATN     HHZ       --   7.85332 -255.26800    Pn
# 13       GE    BOAB     BHZ       --   8.24177 -252.58100    Pn
# ...

# %%
GNNE['New'] = Gsub['Azimuth'].apply(CosAzm30)
GNNE['Tmp'] = GNNE['Residual']*GNNE['New']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
GNNE['Tmp'].mean()/GNNE['New'].mean()
# Out:
# 0.11758464971049938

# %%
GSSW['New'] = Gsub['Azimuth'].apply(CosAzm30)
GSSW['Tmp'] = GSSW['Residual']*GSSW['New']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
GSSW['Tmp'].mean()/GSSW['New'].mean()
# Out:
# -0.14123576840482782

# %%
GSSW.describe()
# Out:
#         Distance     Azimuth   Residual     Weight        New        Tmp
# count  38.000000   38.000000  38.000000  38.000000  38.000000  38.000000
# mean   61.804245  207.308342  -0.189474   1.002368  -0.513732   0.072557
# std    17.827167   60.769217   1.396867   0.112308   0.257536   0.852199
# min    21.087800  126.306000  -2.000000   0.660000  -0.985103  -3.614945
# 25%    50.805850  151.910000  -1.150000   0.962500  -0.690340  -0.232382
# 50%    60.601100  183.867000  -0.200000   1.060000  -0.513428   0.070726
# 75%    73.130600  270.443250   0.375000   1.060000  -0.279016   0.506728
# max    99.194000  296.142000   3.900000   1.110000  -0.067284   1.318980

# %%
Gsub
# Out:
#     Network Station Channel Location  Distance    Azimuth Phase  \
# 0        GI    RETA     HHZ       --   2.02720 -254.81000    Pn
# 1        GI    HUEH     HHZ       --   2.15059 -276.93660    Pn
# 2        GI    PETF     HHZ       --   4.13226 -296.92910    Pn
# 3        GI    CHIE     HHZ       --   4.26002 -263.75560    Pn
# 4        SV    MTO3     HHZ       --   4.26511 -261.58860    Pn
# 5        SV    SNET     BHZ       --   4.55643 -253.03000    Pn
# 6        GI    IZAB     HHZ       --   4.99229 -278.25460    Pn
# 7        CU    TGUH     BHZ       00   6.31780 -261.66880    Pn
# 8         G     UNM     BHZ       00   6.72410 -410.15500    Pn
# 9        NU    CRIN     HHZ       --   6.88807 -250.81000    Pn
# 10       NU    CNGN     HHZ       --   7.27838 -250.33500    Pn
# 11       IU    TEIG     BHZ       00   7.29305 -315.48500    Pn
# 12       NU    MATN     HHZ       --   7.85332 -255.26800    Pn
# 13       GE    BOAB     BHZ       --   8.24177 -252.58100    Pn
# ...

# %%
Gsub['Date'] = Gsub['Arrival Time'].str.split('T').str[0]

# %%
Gsub['Time'] = Gsub['Arrival Time'].str.split('T').str[1]

# %%
Gsub
# Out:
#     Network Station Channel Location  Distance    Azimuth Phase  \
# 0        GI    RETA     HHZ       --   2.02720 -254.81000    Pn
# 1        GI    HUEH     HHZ       --   2.15059 -276.93660    Pn
# 2        GI    PETF     HHZ       --   4.13226 -296.92910    Pn
# 3        GI    CHIE     HHZ       --   4.26002 -263.75560    Pn
# 4        SV    MTO3     HHZ       --   4.26511 -261.58860    Pn
# 5        SV    SNET     BHZ       --   4.55643 -253.03000    Pn
# 6        GI    IZAB     HHZ       --   4.99229 -278.25460    Pn
# 7        CU    TGUH     BHZ       00   6.31780 -261.66880    Pn
# 8         G     UNM     BHZ       00   6.72410 -410.15500    Pn
# 9        NU    CRIN     HHZ       --   6.88807 -250.81000    Pn
# 10       NU    CNGN     HHZ       --   7.27838 -250.33500    Pn
# 11       IU    TEIG     BHZ       00   7.29305 -315.48500    Pn
# 12       NU    MATN     HHZ       --   7.85332 -255.26800    Pn
# 13       GE    BOAB     BHZ       --   8.24177 -252.58100    Pn
# ...

# %%
grouped = Gsub['Residual'].groupby(Gsub['Location'])
grouped.describe()
# Out:
#           count      mean       std  min  25%   50%    75%  max
# Location
# --         56.0  0.176786  1.026201 -2.0 -0.6  0.20  0.925  3.0
# 00         26.0  0.353846  1.409746 -1.4 -0.6  0.05  0.500  3.7
# 01          2.0 -0.100000  0.848528 -0.7 -0.4 -0.10  0.200  0.5
# 10         45.0 -0.235556  1.432917 -2.8 -1.2 -0.50  0.300  3.9

# %%
Gsub['Arrival Time'] = Gsub['Arrival Time'].str.split('Z').str[0]
Gsub
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Network Station Channel Location  Distance  Azimuth  Phase  \
# 129      IU    CTAO     BHZ       10   122.862  255.811  PKPdf
# 130      AU     TOO     BHZ       --   123.356  234.947  PKPdf
# 137      II    KAPI     BHZ       10   145.616  283.697  PKPdf
# 138      IU    NWAO     BHZ       10   146.774  232.392  PKPdf
# 139      IU    MBWA     BHZ       10   147.682  254.531  PKPdf
#
#                Arrival Time     Status  Residual  Weight
# 129  2017-09-08T05:08:09.24  automatic       1.0    0.97
# ...

# %%
Gsub['Arrival Time'] = pd.to_datetime(Gsub['Arrival Time'].str.replace('T',' '))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Gnew = Gsub[['Arrival Time','Distance']]

# %%
# %matplotlib inline
Gnew.plot(x='Arrival Time', y='Distance')

# %%
df = pd.DataFrame({'int_col' : [1,2,6,8,-1], 'float_col' : [0.1, 0.2,0.3,10.1,4.0], 
 'str_col' : ['a','b','b','c','a']})

# %%
other =  pd.DataFrame({'str_col' : ['a','b'], 'some_val' : [1, 2]})

# %%
pd.merge(df,other,on='str_col',how='inner')
# Out:
#    float_col  int_col str_col  some_val
# 0        0.1        1       a         1
# 1        4.0       -1       a         1
# 2        0.2        2       b         2
# 3        0.3        6       b         2

# %%
Gsub
# Out:
#     Network Station Channel Location  Distance  Azimuth  Phase  \
# 129      IU    CTAO     BHZ       10   122.862  255.811  PKPdf
# 130      AU     TOO     BHZ       --   123.356  234.947  PKPdf
# 137      II    KAPI     BHZ       10   145.616  283.697  PKPdf
# 138      IU    NWAO     BHZ       10   146.774  232.392  PKPdf
# 139      IU    MBWA     BHZ       10   147.682  254.531  PKPdf
#
#                 Arrival Time     Status  Residual  Weight
# 129  2017-09-08T05:08:09.24Z  automatic       1.0    0.97
# 130  2017-09-08T05:08:12.12Z  automatic       2.9    0.96
# 137  2017-09-08T05:08:51.14Z  automatic       1.5    0.84
# 138  2017-09-08T05:08:52.77Z  automatic       1.2    0.83
# 139  2017-09-08T05:08:53.69Z  automatic       0.6    0.83

# %%
Gdata
# Out:
#     Network Station Channel Location   Distance    Azimuth   Phase  \
# 0        GI    RETA     HHZ       --    2.02720  105.19000      Pn
# 1        GI    HUEH     HHZ       --    2.15059   83.06340      Pn
# 2        GI    PETF     HHZ       --    4.13226   63.07090      Pn
# 3        GI    CHIE     HHZ       --    4.26002   96.24440      Pn
# 4        SV    MTO3     HHZ       --    4.26511   98.41140      Pn
# 5        SV    SNET     BHZ       --    4.55643  106.97000      Pn
# 6        GI    IZAB     HHZ       --    4.99229   81.74540      Pn
# 7        CU    TGUH     BHZ       00    6.31780   98.33120      Pn
# 8         G     UNM     BHZ       00    6.72410  309.84500      Pn
# 9        NU    CRIN     HHZ       --    6.88807  109.19000      Pn
# 10       NU    CNGN     HHZ       --    7.27838  109.66500      Pn
# 11       IU    TEIG     BHZ       00    7.29305   44.51500      Pn
# 12       NU    MATN     HHZ       --    7.85332  104.73200      Pn
# ...
